# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install scikit-surprise==1.0.6
# Out:
# Collecting scikit-surprise==1.0.6
#   Downloading https://files.pythonhosted.org/packages/4d/fc/cd4210b247d1dca421c25994740cbbf03c5e980e31881f10eaddf45fdab0/scikit-surprise-1.0.6.tar.gz (3.3MB)
#      |████████████████████████████████| 3.3MB 2.9MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise==1.0.6) (1.0.1)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise==1.0.6) (1.19.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise==1.0.6) (1.4.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise==1.0.6) (1.15.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.0.6-cp37-cp37m-linux_x86_64.whl size=1624123 sha256=e4a087899060d5d7a62d7fc764f6f6be2606168b23c730db162b9b5b3e9921d8
#   Stored in directory: /root/.cache/pip/wheels/ec/c0/55/3a28eab06b53c220015063ebbdb81213cd3dcbb72c088251ec
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.0.6

# %%
import numpy as np
import pandas as pd
from collections import defaultdict
from surprise import NMF, accuracy, Trainset
from tqdm.auto import tqdm
import json
import ast

# %% [markdown]
# # Load trainset

# %%
with open('/content/drive/MyDrive/Colab Notebooks/Anime Recommendation System/Data/Rating/trainset.json', 'r') as f:
    traindata = json.load(f)

# %%
traindata.keys()
# Out:
# dict_keys(['ur_dict', 'ir_dict', 'n_users', 'n_items', 'n_ratings', 'offset', 'rating_scale', 'raw2inner_id_users', 'raw2inner_id_items'])

# %%
rating_scale = tuple(traindata['rating_scale'])

# %%
n_users, n_items, n_ratings, offset = traindata['n_users'], traindata['n_items'], traindata['n_ratings'], traindata['offset']

# %%
ur_dict = {}
for key in tqdm(traindata['ur_dict'].keys()):
    ur_dict[int(key)] = [tuple(x) for x in traindata['ur_dict'][key]]
ur = defaultdict(list, ur_dict)

ir_dict = {}
for key in tqdm(traindata['ir_dict'].keys()):
    ir_dict[int(key)] = [tuple(x) for x in traindata['ir_dict'][key]]
ir = defaultdict(list, ir_dict)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=73515.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10809.0), HTML(value='')))

# %%
raw2inner_id_users = {}
for key in tqdm(traindata['raw2inner_id_users'].keys()):
    raw2inner_id_users[int(key)] = traindata['raw2inner_id_users'][key]

raw2inner_id_items = {}
for key in tqdm(traindata['raw2inner_id_items'].keys()):
    raw2inner_id_items[int(key)] = traindata['raw2inner_id_items'][key]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=73515.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10809.0), HTML(value='')))

# %%
trainset = Trainset(ur=ur, 
                    ir=ir, 
                    n_users=n_users, 
                    n_items=n_items, 
                    n_ratings=n_ratings, 
                    rating_scale=rating_scale, 
                    offset=offset, 
                    raw2inner_id_users=raw2inner_id_users, 
                    raw2inner_id_items=raw2inner_id_items)

# %% [markdown]
# # Load testset

# %%
with open('/content/drive/MyDrive/Colab Notebooks/Anime Recommendation System/Data/Rating/testset.json', 'r') as f:
    testset = json.load(f)
testset = [tuple(x) for x in testset['testset']]

# %% [markdown]
# # Train

# %%
model = NMF(n_factors=400, n_epochs=100, verbose=True)
model.fit(trainset)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Processing epoch 30
# Processing epoch 31
# Processing epoch 32
# Processing epoch 33
# Processing epoch 34
# Processing epoch 35
# Processing epoch 36
# Processing epoch 37
# Processing epoch 38
# Processing epoch 39
# Processing epoch 40
# Processing epoch 41
# Processing epoch 42
# Processing epoch 43
# Processing epoch 44
# Processing epoch 45
# Processing epoch 46
# Processing epoch 47
# Processing epoch 48
# Processing epoch 49
# Processing epoch 50
# Processing epoch 51
# Processing epoch 52
# Processing epoch 53
# Processing epoch 54
# Processing epoch 55
# Processing epoch 56
# Processing epoch 57
# Processing epoch 58
# Processing epoch 59
# Processing epoch 60
# Processing epoch 61
# Processing epoch 62
# Processing epoch 63
# Processing epoch 64
# Processing epoch 65
# Processing epoch 66
# Processing epoch 67
# Processing epoch 68
# Processing epoch 69
# Processing epoch 70
# Processing epoch 71
# Processing epoch 72
# Processing epoch 73
# Processing epoch 74
# Processing epoch 75
# Processing epoch 76
# Processing epoch 77
# Processing epoch 78
# Processing epoch 79
# Processing epoch 80
# Processing epoch 81
# Processing epoch 82
# Processing epoch 83
# Processing epoch 84
# Processing epoch 85
# Processing epoch 86
# Processing epoch 87
# Processing epoch 88
# Processing epoch 89
# Processing epoch 90
# Processing epoch 91
# Processing epoch 92
# Processing epoch 93
# Processing epoch 94
# Processing epoch 95
# Processing epoch 96
# Processing epoch 97
# Processing epoch 98
# Processing epoch 99

# %% [markdown]
# # Evaluate

# %%
predictions = model.test(testset)
accuracy.rmse(predictions)
accuracy.mae(predictions)
# Out:
# RMSE: 2.4397
# MAE:  1.7816
# 1.7816352745384707

# %%
# ndcg
testdata = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Anime Recommendation System/Data/Test/test_data.csv')
sum = 0.0
for _, row in tqdm(testdata.iterrows()):
    rele = np.array(ast.literal_eval(row['ratings']))
    if rele.shape[0] == 0:
        sum += 1.0
        continue
    
    if rele.sum() == 0:
        sum += 1.0
        continue
    
    pred = np.array([model.predict(row['user_id'], iid).est for iid in ast.literal_eval(row['anime_ids'])])
    dlog2 = np.log2(np.arange(rele.shape[0]) + 2)
    tmp_df = pd.DataFrame({'rele': rele, 'pred': pred})
    tmp_df = tmp_df.sort_values(by=['pred'], ascending=False)
    dcg = (tmp_df['rele'].values / dlog2).sum()

    rele[::-1].sort()
    idcg = (rele / dlog2).sum()
    sum += dcg / idcg

sum / n_users
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# 0.9505897142935198
